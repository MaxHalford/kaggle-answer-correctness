# %% [markdown]
# # Solution

# %%
KAGGLE_KERNEL = False

# %% [markdown]
# ## Setup

# %%
import pathlib
import pandas as pd

data_dir = pathlib.Path('../input/riiid-test-answer-prediction/' if KAGGLE_KERNEL else 'data')

if data_dir.joinpath('train.pkl').exists():
    print('Loading .pkl')
    train = pd.read_pickle(data_dir.joinpath('train.pkl'))
    
else:

    print('Loading .csv')
    dtypes = {
        'row_id': 'int64',
        'timestamp': 'int64',
        'user_id': 'int32',
        'content_id': 'int16',
        'content_type_id': 'int8',
        'task_container_id': 'int16',
        'user_answer': 'int8',
        'answered_correctly': 'int8',
        'prior_question_elapsed_time': 'float32',
        'prior_question_had_explanation': 'boolean'
    }
    train = pd.read_csv(
        'data/train.csv',
        index_col='row_id',
        dtype=dtypes
    )
    train.to_pickle('data/train.pkl')

train.head(5)
# Out:
# Loading .pkl
#         timestamp  user_id  content_id  content_type_id  task_container_id  \
# row_id
# 0               0      115        5692                0                  1
# 1           56943      115        5716                0                  2
# 2          118363      115         128                0                  0
# 3          131167      115        7860                0                  3
# 4          137965      115        7922                0                  4
#
#         user_answer  answered_correctly  prior_question_elapsed_time  \
# row_id
# 0                 3                   1                          NaN
# 1                 2                   1                      37000.0
# 2                 0                   1                      55000.0
# 3                 0                   1                      19000.0
# 4                 1                   1                      11000.0
#
#         prior_question_had_explanation
# row_id
# 0                                 <NA>
# 1                                False
# 2                                False
# 3                                False
# 4                                False

# %% [markdown]
# The `task_container_id` variable is supposed to be monotonically increasing for each user. But that doesn't seem to be the case. For instance, see user 115. Therefore, I renumber the tasks to make sure they're monotonically increasing for each user.

# %%
train['task_container_id'] = train.groupby('user_id')['task_container_id'].transform(lambda x: pd.factorize(x)[0]).astype('int16')
train.head()
# Out:
#         timestamp  user_id  content_id  content_type_id  task_container_id  \
# row_id
# 0               0      115        5692                0                  0
# 1           56943      115        5716                0                  1
# 2          118363      115         128                0                  2
# 3          131167      115        7860                0                  3
# 4          137965      115        7922                0                  4
#
#         user_answer  answered_correctly  prior_question_elapsed_time  \
# row_id
# 0                 3                   1                          NaN
# 1                 2                   1                      37000.0
# 2                 0                   1                      55000.0
# 3                 0                   1                      19000.0
# 4                 1                   1                      11000.0
#
#         prior_question_had_explanation
# row_id
# 0                                 <NA>
# 1                                False
# 2                                False
# 3                                False
# 4                                False

# %% [markdown]
# We can now iterate over batches of the training data. The idea is that each batch is going to behave like the data that the `env.iter_test` function will yield in the Kaggle kernel. We will thus call each batch a "group" to adopt the same terminology.

# %%
def iter_groups(train):
    
    correct = {}
    
    for _, group in iter(train.groupby('task_container_id')):
    
        yield (
            group.drop(columns=['user_answer', 'answered_correctly']),
            correct
        )
        
        users = group.groupby('user_id', sort=False)
        correct = users['answered_correctly'].apply(list).to_dict()
        
groups = iter_groups(train[:10_000])
group, prev_correct = next(groups)
group.head()
# Out:
#         timestamp  user_id  content_id  content_type_id  task_container_id  \
# row_id
# 0               0      115        5692                0                  0
# 46              0      124        7900                0                  0
# 76              0     2746        5273                0                  0
# 96              0     5382        5000                0                  0
# 224             0     8623        3915                0                  0
#
#         prior_question_elapsed_time  prior_question_had_explanation
# row_id
# 0                               NaN                            <NA>
# 46                              NaN                            <NA>
# 76                              NaN                            <NA>
# 96                              NaN                            <NA>
# 224                             NaN                            <NA>

# %%
next_group, next_prev_correct = next(groups)
next_group.head()
# Out:
#         timestamp  user_id  content_id  content_type_id  task_container_id  \
# row_id
# 1           56943      115        5716                0                  1
# 47          32683      124        7876                0                  1
# 77          21592     2746         758                0                  1
# 97          39828     5382        3944                0                  1
# 225         38769     8623        4750                0                  1
#
#         prior_question_elapsed_time  prior_question_had_explanation
# row_id
# 1                           37000.0                           False
# 47                          26000.0                           False
# 77                          28000.0                           False
# 97                          24000.0                           False
# 225                         16000.0                           False

# %%
import itertools

for user in itertools.islice(next_prev_correct, 5):
    print(user, next_prev_correct[user])
# Out:
# 115 [1]
# 124 [1]
# 2746 [0]
# 5382 [1]
# 8623 [1]

# %% [markdown]
# As you can see, this first group contains the first interaction of each user. The next group contains the second interaction, along with the correctness information for the first group.
#
# The goal is now to build stateful feature extractors. Each such feature extractor should provide the ability to produce features for each row in a group. The feature extractor should then be able to update itself with the new information provided by the group. Here is the interface:

# %%
import abc
import re

class Extractor(abc.ABC):
    
    @abc.abstractmethod
    def transform(self, group):
        pass
    
class SupervisedExtractor(Extractor):
    
    @abc.abstractmethod
    def partial_fit(self, group, prev_correct):
        pass

# %% [markdown]
# By doing things this way, we'll be able to apply the same code for both training and testing. More code reuse means less bugs, at least in my book.

# %% [markdown]
# ## Feature extraction

# %%
import statistics

def update_avg(avg, n, new):
    m = len(new)
    n += m
    return avg + m * (statistics.mean(new) - avg) / n, n

# %%
import collections

class AvgCorrect(SupervisedExtractor):
    
    def __init__(self):
        self.avgs = collections.defaultdict(lambda: (.6, 20))
    
    def partial_fit(self, group, prev_correct):
        for user_id, correct in prev_correct.items():
             self.avgs[user_id] = update_avg(*self.avgs[user_id], correct)
    
    def transform(self, group):
        return pd.Series(
            (self.avgs[user_id][0] for user_id in group.user_id),
            name='avg_correct',
            index=group.index
        )
    
extractor = AvgCorrect()
extractor.partial_fit(next_group, next_prev_correct)
extractor.transform(next_group).head()
# Out:
# row_id
# 1      0.619048
# 47     0.619048
# 77     0.571429
# 97     0.619048
# 225    0.619048
# Name: avg_correct, dtype: float64

# %%
prev_correct
# Out:
# {24418: [1]}

# %%
class AvgCorrect(SupervisedExtractor):
    
    def __init__(self):
        self.avgs = collections.defaultdict(lambda: (.6, 20))
    
    def partial_fit(self, group, prev_correct):
        for user_id, correct in prev_correct.items():
             self.avgs[user_id] = update_avg(*self.avgs[user_id], correct)
    
    def transform(self, group):
        return pd.Series(
            (self.avgs[user_id][0] for user_id in group.user_id),
            name='avg_correct',
            index=group.index
        )

# %% [markdown]
# Now let's extract features for the training set.

# %%
# %%prun

import chime
import tqdm

extractors = ExtractorUnion(
    AvgCorrect()
)

with open('data/train_features.csv', 'w') as out:

    for i, (group, prev_correct) in tqdm.tqdm(enumerate(iter_groups(train[:10000])), total=10_000, position=0):    
        features = extractors.transform(group)
        extractors.partial_fit(group, prev_correct)
        
        if i == 0:
            features.to_csv(out)
        else:
            features.to_csv(out, mode='a', header=False)
            
chime.success()
# Out:
#  49%|████▉     | 4890/10000 [00:16<00:17, 296.38it/s]
#          25334458 function calls (25079487 primitive calls) in 16.543 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 4892130/4887240    0.953    0.000    1.583    0.000 {built-in method builtins.isinstance}
# 48901/24451    0.497    0.000    3.036    0.000 base.py:289(__new__)
#   1711577    0.416    0.000    0.579    0.000 generic.py:10(_check)
#      9781    0.292    0.000    0.516    0.000 managers.py:228(_rebuild_blknos_and_blklocs)
# 234736/220066    0.290    0.000    0.343    0.000 {built-in method numpy.array}
#   2596733    0.283    0.000    0.312    0.000 {built-in method builtins.getattr}
#     63582    0.277    0.000    0.277    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      4890    0.251    0.000    2.411    0.000 managers.py:1267(_slice_take_blocks_ax0)
#     39129    0.240    0.000    1.512    0.000 algorithms.py:1586(take_nd)
#    303221    0.238    0.000    0.593    0.000 common.py:1460(is_extension_array_dtype)
#     34231    0.213    0.000    0.324    0.000 {pandas._libs.lib.infer_dtype}
#    117380    0.209    0.000    0.582    0.000 _dtype.py:333(_name_get)
#    489189    0.199    0.000    0.200    0.000 {built-in method builtins.hasattr}
#    303221    0.199    0.000    0.285    0.000 base.py:413(find)
#    312970    0.199    0.000    0.396    0.000 common.py:1600(_is_dtype_type)
#    381434    0.196    0.000    0.879    0.000 base.py:256(is_dtype)
# 1083664/902043    0.191    0.000    0.261    0.000 {built-in method builtins.len}
#   1333030    0.177    0.000    0.188    0.000 {built-in method builtins.issubclass}
#    102701    0.177    0.000    0.177    0.000 {built-in method numpy.empty}
#     39129    0.169    0.000    0.617    0.000 algorithms.py:1457(_get_take_nd_function)
#     41908    0.163    0.000    2.037    0.000 series.py:201(__init__)
#      9780    0.151    0.000    0.221    0.000 {pandas._libs.lib.maybe_convert_objects}
#     95701    0.149    0.000    0.327    0.000 generic.py:5132(__setattr__)
#     76144    0.135    0.000    0.347    0.000 blocks.py:124(__init__)
#     71250    0.114    0.000    0.172    0.000 base.py:459(_simple_new)
#      4891    0.108    0.000    9.589    0.002 <ipython-input-228-a1d7057a6371>:1(iter_groups)
#     29340    0.106    0.000    0.698    0.000 blocks.py:2650(get_block_type)
#    185828    0.103    0.000    0.270    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#     61470    0.102    0.000    0.102    0.000 generic.py:195(__init__)
#         1    0.098    0.098   16.542   16.542 <string>:1(<module>)
#     24451    0.095    0.000    0.095    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      1456    0.090    0.000    0.090    0.000 {method 'acquire' of '_thread.lock' objects}
#    117361    0.089    0.000    0.346    0.000 dtypes.py:901(is_dtype)
#     14672    0.084    0.000    0.084    0.000 {pandas._libs.algos.take_1d_int64_int64}
#     34236    0.083    0.000    0.244    0.000 blocks.py:292(getitem_block)
#      4890    0.083    0.000    0.158    0.000 function_base.py:4218(delete)
#     24455    0.082    0.000    0.999    0.000 blocks.py:1233(take_nd)
#    146705    0.081    0.000    0.364    0.000 common.py:530(is_categorical_dtype)
#    161372    0.081    0.000    0.443    0.000 common.py:456(is_period_dtype)
#      4891    0.081    0.000    0.094    0.000 {method 'factorize' of 'pandas._libs.hashtable.Int64HashTable' objects}
#     81034    0.080    0.000    0.137    0.000 blocks.py:237(mgr_locs)
#      4890    0.080    0.000    2.416    0.000 ops.py:158(apply)
#     88021    0.079    0.000    0.271    0.000 dtypes.py:1113(is_dtype)
#     41909    0.077    0.000    0.244    0.000 base.py:4077(__getitem__)
#    176072    0.077    0.000    0.122    0.000 numerictypes.py:293(issubclass_)
#     88036    0.077    0.000    0.206    0.000 numerictypes.py:365(issubdtype)
#      4891    0.076    0.000    0.547    0.000 grouper.py:601(get_grouper)
#    117380    0.076    0.000    0.282    0.000 _dtype.py:319(_name_includes_bit_suffix)
#     39120    0.076    0.000    0.290    0.000 common.py:218(asarray_tuplesafe)
#    166275    0.073    0.000    0.118    0.000 common.py:1565(_get_dtype)
#      9780    0.072    0.000    0.090    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#      4890    0.071    0.000    2.547    0.001 concat.py:295(__init__)
#      4890    0.070    0.000    0.577    0.000 managers.py:1682(form_blocks)
#     88024    0.070    0.000    0.208    0.000 common.py:194(is_object_dtype)
#     68467    0.069    0.000    0.069    0.000 {built-in method numpy.arange}
#    107584    0.068    0.000    0.136    0.000 common.py:422(is_timedelta64_dtype)
#      4890    0.066    0.000    0.066    0.000 {pandas._libs.writers.write_csv_rows}
#    132032    0.065    0.000    0.350    0.000 common.py:492(is_interval_dtype)
#     46799    0.065    0.000    0.195    0.000 base.py:494(_shallow_copy)
#     51694    0.064    0.000    0.266    0.000 blocks.py:256(make_block_same_class)
#     27238    0.063    0.000    0.134    0.000 base.py:1032(__iter__)
#     14671    0.062    0.000    0.447    0.000 managers.py:955(iget)
# 185834/176054    0.061    0.000    0.288    0.000 _asarray.py:16(asarray)
#     69145    0.060    0.000    0.101    0.000 series.py:442(name)
# 44012/34232    0.060    0.000    0.288    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     14670    0.059    0.000    0.409    0.000 missing.py:193(_isna_ndarraylike)
#     29342    0.059    0.000    0.081    0.000 base.py:4030(__contains__)
#     41909    0.058    0.000    0.232    0.000 numeric.py:105(_shallow_copy)
#      4890    0.058    0.000    0.491    0.000 csvs.py:34(__init__)
#    157170    0.057    0.000    0.082    0.000 inference.py:322(is_hashable)
#      9780    0.057    0.000    3.535    0.000 generic.py:4205(reindex)
#     24451    0.056    0.000    0.517    0.000 base.py:4190(equals)
#     14672    0.056    0.000    0.936    0.000 frame.py:2866(__getitem__)
#      9780    0.056    0.000    0.673    0.000 construction.py:389(sanitize_array)
#    164164    0.056    0.000    0.074    0.000 base.py:563(__len__)
#     41908    0.055    0.000    0.066    0.000 managers.py:1499(__init__)
#    215167    0.054    0.000    0.081    0.000 common.py:180(<lambda>)
#     14671    0.054    0.000    0.113    0.000 _asarray.py:223(require)
#      9788    0.054    0.000    0.210    0.000 cast.py:441(maybe_promote)
# 46798/41908    0.054    0.000    0.634    0.000 generic.py:5114(__getattr__)
#     19560    0.053    0.000    0.119    0.000 cast.py:1559(construct_1d_object_array_from_listlike)
#      4890    0.053    0.000    0.782    0.000 csvs.py:330(_save_chunk)
#     24450    0.053    0.000    0.814    0.000 blocks.py:2696(make_block)
#     14671    0.051    0.000    0.191    0.000 numeric.py:50(__new__)
#      9781    0.051    0.000    0.608    0.000 groupby.py:483(__init__)
#     19562    0.051    0.000    0.157    0.000 managers.py:122(__init__)
#      9780    0.051    0.000    0.700    0.000 series.py:820(take)
#     65026    0.050    0.000    0.050    0.000 {pandas._libs.algos.ensure_int64}
#     48905    0.050    0.000    0.221    0.000 common.py:1330(is_bool_dtype)
#    100594    0.049    0.000    0.049    0.000 {built-in method _abc._abc_instancecheck}
#     19562    0.049    0.000    0.049    0.000 {method 'take' of 'numpy.ndarray' objects}
#     14671    0.049    0.000    0.848    0.000 generic.py:3523(_get_item_cache)
#     73352    0.047    0.000    0.126    0.000 base.py:5648(maybe_extract_name)
#     92918    0.047    0.000    0.064    0.000 common.py:1733(pandas_dtype)
#     89321    0.047    0.000    0.048    0.000 {method 'format' of 'str' objects}
#     73358    0.046    0.000    0.235    0.000 common.py:381(is_datetime64tz_dtype)
#     58686    0.044    0.000    0.090    0.000 {pandas._libs.lib.is_list_like}
#     76822    0.044    0.000    0.072    0.000 managers.py:1580(internal_values)
#      9780    0.044    0.000    0.099    0.000 config.py:112(_set_option)
#      9780    0.044    0.000    0.991    0.000 base.py:2951(get_indexer)
#     85938    0.043    0.000    0.043    0.000 {pandas._libs.lib.is_scalar}
#     23028    0.043    0.000    0.053    0.000 fractions.py:84(__new__)
#     29340    0.042    0.000    0.093    0.000 common.py:224(is_sparse)
#     29343    0.042    0.000    0.104    0.000 managers.py:202(shape)
#      9780    0.042    0.000    0.139    0.000 cast.py:1301(maybe_cast_to_datetime)
#    215167    0.042    0.000    0.042    0.000 common.py:178(classes)
#      4890    0.042    0.000    1.162    0.000 base.py:5251(drop)
#      4891    0.041    0.000    0.596    0.000 algorithms.py:503(factorize)
#     97802    0.041    0.000    0.053    0.000 common.py:905(is_datetime64_any_dtype)
#     53793    0.041    0.000    0.136    0.000 common.py:750(is_signed_integer_dtype)
#      4891    0.040    0.000    0.040    0.000 {pandas._libs.lib.generate_slices}
#     17458    0.040    0.000    1.198    0.000 ops.py:934(__iter__)
#     14671    0.040    0.000    0.247    0.000 frame.py:3174(_box_col_values)
#      9782    0.039    0.000    0.255    0.000 algorithms.py:69(_ensure_data)
#      4890    0.039    0.000    0.086    0.000 managers.py:1810(_stack_arrays)
#     14670    0.039    0.000    0.338    0.000 missing.py:358(array_equivalent)
#      4891    0.039    0.000    9.779    0.002 std.py:1143(__iter__)
#     59365    0.038    0.000    0.071    0.000 series.py:492(name)
#      7676    0.038    0.000    0.155    0.000 statistics.py:104(_sum)
#     29342    0.038    0.000    0.064    0.000 generic.py:5086(__finalize__)
#     29340    0.037    0.000    0.037    0.000 _internal.py:830(npy_ctypes_check)
#     97803    0.037    0.000    0.052    0.000 common.py:188(<lambda>)
#      9780    0.036    0.000    0.087    0.000 numeric.py:2287(array_equal)
#      4891    0.036    0.000    0.060    0.000 sorting.py:503(get_group_index_sorter)
#     88024    0.036    0.000    0.732    0.000 base.py:5551(ensure_index)
#    138301    0.035    0.000    0.035    0.000 {built-in method __new__ of type object at 0x10bc62568}
#      9781    0.034    0.000    0.435    0.000 managers.py:730(get_slice)
#     19560    0.033    0.000    0.683    0.000 managers.py:1531(from_array)
#      4890    0.033    0.000    3.724    0.001 groupby.py:825(apply)
#      4890    0.033    0.000    4.307    0.001 generic.py:3885(_drop_axis)
#    117380    0.032    0.000    0.032    0.000 _dtype.py:36(_kind_name)
#      4890    0.032    0.000    1.400    0.000 generic.py:2991(to_csv)
#     63582    0.032    0.000    0.148    0.000 construction.py:338(extract_array)
#     48906    0.032    0.000    0.071    0.000 common.py:608(is_dtype_equal)
#     14670    0.032    0.000    0.290    0.000 base.py:5718(_maybe_cast_data_without_dtype)
#      4891    0.032    0.000    0.645    0.000 frame.py:6390(groupby)
#      4890    0.032    0.000    0.032    0.000 {built-in method pandas._libs.missing.isnaobj}
#     24460    0.031    0.000    0.482    0.000 missing.py:130(_isna)
#     19562    0.031    0.000    2.367    0.000 frame.py:440(__init__)
#    100594    0.031    0.000    0.080    0.000 abc.py:137(__instancecheck__)
#      4890    0.031    0.000    0.086    0.000 missing.py:235(_isna_string_dtype)
#    188633    0.030    0.000    0.030    0.000 blocks.py:233(mgr_locs)
#      9780    0.030    0.000    0.532    0.000 base.py:978(_format_native_types)
#     76144    0.030    0.000    0.030    0.000 blocks.py:135(_check_ndim)
#       647    0.030    0.000    0.030    0.000 socket.py:342(send)
#     14670    0.030    0.000    0.054    0.000 generic.py:334(_construct_axes_from_arguments)
#     76822    0.030    0.000    0.102    0.000 series.py:540(_values)
#     29341    0.030    0.000    0.037    0.000 generic.py:377(_get_axis)
#      4890    0.029    0.000    2.398    0.000 concat.py:456(get_result)
#      4890    0.029    0.000    2.557    0.001 generic.py:4493(_reindex_with_indexers)
#      4890    0.029    0.000    0.082    0.000 base.py:5789(_try_convert_to_int_array)
#     71250    0.029    0.000    0.029    0.000 base.py:540(_reset_identity)
#     34231    0.029    0.000    0.033    0.000 series.py:398(_set_axis)
#      4890    0.029    0.000    3.508    0.001 groupby.py:874(_python_apply_general)
#      7677    0.029    0.000    0.154    0.000 managers.py:1556(get_slice)
#    186512    0.029    0.000    0.029    0.000 {built-in method builtins.hash}
#      4891    0.028    0.000    2.485    0.001 managers.py:1208(reindex_indexer)
#     83360    0.027    0.000    0.027    0.000 {method 'get' of 'dict' objects}
#      4890    0.027    0.000    0.829    0.000 csvs.py:313(_save)
#      4891    0.027    0.000    0.109    0.000 grouper.py:414(__init__)
#    118730    0.026    0.000    0.026    0.000 managers.py:1542(_block)
#      4890    0.026    0.000    4.984    0.001 <ipython-input-250-5169d0567ee5>:13(transform)
#      4891    0.026    0.000    0.849    0.000 grouper.py:582(_make_codes)
#      4890    0.025    0.000    1.064    0.000 generic.py:418(_wrap_applied_output)
#     39120    0.025    0.000    0.065    0.000 common.py:1296(is_float_dtype)
#     29340    0.025    0.000    0.075    0.000 common.py:1025(is_datetime_or_timedelta_dtype)
#      9780    0.024    0.000    0.313    0.000 cast.py:87(maybe_convert_platform)
#      4890    0.024    0.000    2.294    0.000 construction.py:237(init_dict)
#     83136    0.024    0.000    0.024    0.000 generic.py:365(_get_axis_number)
#     22507    0.023    0.000    0.121    0.000 {built-in method builtins.sum}
#     37022    0.023    0.000    0.023    0.000 blocks.py:287(_slice)
# 39120/34230    0.023    0.000    0.536    0.000 {built-in method builtins.all}
#     29340    0.022    0.000    0.291    0.000 common.py:1180(needs_i8_conversion)
#     24450    0.022    0.000    0.129    0.000 common.py:566(is_string_dtype)
#     34231    0.022    0.000    0.038    0.000 managers.py:1569(dtype)
#      4891    0.021    0.000    0.171    0.000 generic.py:3542(_slice)
#      4890    0.021    0.000    1.272    0.000 <ipython-input-242-ec43a157a203>:12(transform)
#     71251    0.021    0.000    0.021    0.000 base.py:1169(name)
#     88029    0.021    0.000    0.061    0.000 managers.py:204(<genexpr>)
#      9781    0.020    0.000    0.787    0.000 ops.py:947(_get_sorted_data)
#      4890    0.020    0.000    0.326    0.000 managers.py:1794(_multi_blockify)
#     29340    0.020    0.000    0.050    0.000 common.py:806(is_unsigned_integer_dtype)
#     88031    0.020    0.000    0.020    0.000 blocks.py:315(dtype)
#      4891    0.020    0.000    0.061    0.000 algorithms.py:272(_check_object_for_strings)
#     14670    0.020    0.000    0.209    0.000 base.py:5664(_maybe_cast_with_dtype)
#      9780    0.020    0.000    0.070    0.000 numeric.py:283(full)
#      9781    0.019    0.000    0.040    0.000 managers.py:655(_consolidate_check)
#      4890    0.019    0.000    0.889    0.000 concat.py:534(_get_concat_axis)
#     73363    0.019    0.000    0.026    0.000 managers.py:206(ndim)
#     14670    0.019    0.000    0.046    0.000 config.py:86(_get_single_key)
#     24611    0.019    0.000    0.019    0.000 {built-in method builtins.max}
#      4890    0.019    0.000    0.693    0.000 managers.py:1642(create_block_manager_from_arrays)
#     29340    0.019    0.000    0.114    0.000 common.py:1541(_is_dtype)
#    112474    0.019    0.000    0.019    0.000 base.py:3864(_values)
#      9781    0.019    0.000    0.108    0.000 base.py:697(take)
#      9788    0.018    0.000    0.050    0.000 cast.py:597(_ensure_dtype_type)
#     19562    0.018    0.000    0.035    0.000 managers.py:128(<listcomp>)
#      4891    0.018    0.000    0.060    0.000 masked.py:88(__getitem__)
#      4890    0.018    0.000    4.350    0.001 generic.py:3849(drop)
#     14671    0.018    0.000    0.060    0.000 base.py:2845(get_loc)
#      7676    0.018    0.000    0.222    0.000 statistics.py:290(mean)
#     14671    0.018    0.000    0.021    0.000 _asarray.py:300(<setcomp>)
#      4890    0.018    0.000    0.070    0.000 cast.py:1193(maybe_infer_to_datetimelike)
#      9780    0.017    0.000    0.588    0.000 base.py:948(to_native_types)
#      4891    0.017    0.000    0.029    0.000 generic.py:1474(_check_label_or_level_ambiguity)
#      9781    0.017    0.000    0.020    0.000 typing.py:809(__new__)
#     14670    0.017    0.000    0.087    0.000 generic.py:5188(_protect_consolidate)
#     34231    0.017    0.000    0.056    0.000 series.py:427(dtype)
#     97803    0.017    0.000    0.017    0.000 common.py:183(classes_and_not_datetimelike)
#     19560    0.017    0.000    0.501    0.000 generic.py:4439(<genexpr>)
#      9781    0.017    0.000    0.261    0.000 managers.py:736(<listcomp>)
#      1443    0.017    0.000    0.017    0.000 {pandas._libs.algos.groupsort_indexer}
#      4890    0.017    0.000    0.017    0.000 {pandas._libs.algos.take_2d_axis0_int16_int16}
#      4890    0.017    0.000    0.245    0.000 generic.py:1646(_gotitem)
#     14670    0.017    0.000    0.025    0.000 config.py:557(_get_root)
#     34236    0.017    0.000    0.023    0.000 blocks.py:111(_simple_new)
#     14670    0.016    0.000    0.056    0.000 base.py:1835(is_object)
#     24452    0.016    0.000    0.176    0.000 {method 'max' of 'numpy.ndarray' objects}
#    112470    0.016    0.000    0.016    0.000 {method 'pop' of 'dict' objects}
#     14670    0.016    0.000    0.058    0.000 common.py:274(maybe_iterable_to_list)
#      4891    0.016    0.000    0.308    0.000 algorithms.py:463(_factorize_array)
#      4890    0.016    0.000    0.016    0.000 {pandas._libs.algos.take_2d_axis1_float32_float32}
#      4890    0.016    0.000    0.016    0.000 {pandas._libs.algos.take_2d_axis1_int64_int64}
#      4890    0.016    0.000    0.016    0.000 {pandas._libs.algos.take_2d_axis0_int8_int8}
#      4890    0.016    0.000    3.097    0.001 frame.py:4007(reindex)
#      7677    0.016    0.000    0.231    0.000 ops.py:955(_chop)
#      4890    0.016    0.000    0.253    0.000 <ipython-input-242-ec43a157a203>:8(partial_fit)
#      4890    0.016    0.000    0.178    0.000 blocks.py:1934(to_native_types)
#      4890    0.015    0.000    0.015    0.000 {pandas._libs.algos.take_2d_axis1_int32_int32}
#      4890    0.015    0.000    0.015    0.000 {built-in method _csv.writer}
#      4890    0.015    0.000    0.862    0.000 csvs.py:158(save)
#      4890    0.015    0.000    0.234    0.000 base.py:3285(reindex)
#     34232    0.015    0.000    0.021    0.000 common.py:149(cast_scalar_indexer)
#     14671    0.014    0.000    0.014    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#      4890    0.014    0.000    0.084    0.000 series.py:1530(to_dict)
#      4890    0.014    0.000    0.352    0.000 ops.py:967(_chop)
#      9780    0.014    0.000    0.030    0.000 inference.py:263(is_dict_like)
#      4890    0.014    0.000    0.015    0.000 config.py:394(__init__)
#      4891    0.014    0.000    0.077    0.000 blocks.py:1735(_slice)
#      4891    0.014    0.000    0.897    0.000 ops.py:286(_get_compressed_codes)
#      4890    0.014    0.000    2.818    0.001 frame.py:3861(_reindex_axes)
#      4890    0.014    0.000    0.283    0.000 base.py:211(__getitem__)
#     19563    0.013    0.000    0.087    0.000 {built-in method builtins.any}
#      4890    0.013    0.000    2.804    0.001 frame.py:3898(_reindex_columns)
#     14670    0.013    0.000    0.047    0.000 <__array_function__ internals>:2(copyto)
#      4890    0.013    0.000    4.958    0.001 concat.py:70(concat)
#      4890    0.013    0.000    0.048    0.000 managers.py:311(_verify_integrity)
#     14670    0.013    0.000    0.067    0.000 generic.py:5202(f)
#     14671    0.013    0.000    0.034    0.000 generic.py:3177(_set_as_cached)
#      7676    0.013    0.000    0.236    0.000 <ipython-input-241-c894885c204c>:3(update_avg)
#     24451    0.013    0.000    0.017    0.000 base.py:516(is_)
#     14671    0.013    0.000    0.028    0.000 base.py:4970(_maybe_cast_indexer)
#     24450    0.013    0.000    0.086    0.000 {method 'all' of 'numpy.ndarray' objects}
#      7676    0.012    0.000    0.029    0.000 fractions.py:401(_add)
#      9781    0.012    0.000    0.018    0.000 managers.py:656(<listcomp>)
#      4890    0.012    0.000    0.293    0.000 generic.py:444(_get_index)
#     14670    0.012    0.000    0.012    0.000 config.py:571(_get_deprecated_option)
#     14670    0.012    0.000    0.035    0.000 common.py:696(is_integer_dtype)
#     76822    0.012    0.000    0.012    0.000 blocks.py:201(internal_values)
#      4891    0.012    0.000    0.034    0.000 blocks.py:1532(__init__)
#     19562    0.012    0.000    0.012    0.000 {method 'fill' of 'numpy.ndarray' objects}
#      9780    0.012    0.000    0.472    0.000 base.py:4269(identical)
#     14671    0.012    0.000    0.012    0.000 blocks.py:319(iget)
#      4890    0.012    0.000    0.206    0.000 indexing.py:1500(_get_slice_axis)
#      4890    0.012    0.000    0.504    0.000 construction.py:329(_homogenize)
#      4890    0.012    0.000    0.488    0.000 series.py:4391(reindex)
#      7676    0.012    0.000    0.017    0.000 statistics.py:232(_convert)
#     14672    0.012    0.000    0.015    0.000 generic.py:382(_get_block_manager_axis)
#     14671    0.012    0.000    0.031    0.000 <__array_function__ internals>:2(can_cast)
#     14678    0.012    0.000    0.080    0.000 {method 'any' of 'numpy.ndarray' objects}
#      4892    0.011    0.000    0.017    0.000 boolean.py:262(__init__)
#         1    0.011    0.011    0.011    0.011 {built-in method _posixsubprocess.fork_exec}
#     14670    0.011    0.000    0.016    0.000 generic.py:362(<dictcomp>)
#      4890    0.011    0.000    1.214    0.000 construction.py:60(arrays_to_mgr)
#      4890    0.011    0.000    0.130    0.000 base.py:789(copy)
#     15352    0.011    0.000    0.037    0.000 statistics.py:158(<genexpr>)
#     14670    0.011    0.000    0.024    0.000 base.py:569(__array__)
#      4890    0.011    0.000    0.019    0.000 _validators.py:218(validate_axis_style_args)
#     24452    0.011    0.000    0.160    0.000 _methods.py:28(_amax)
#      4891    0.011    0.000    0.930    0.000 ops.py:136(_get_splitter)
#      4890    0.011    0.000    0.031    0.000 common.py:152(get_filepath_or_buffer)
#     24450    0.011    0.000    0.081    0.000 common.py:595(condition)
#     24460    0.011    0.000    0.493    0.000 missing.py:47(isna)
#      9780    0.010    0.000    0.024    0.000 series.py:385(_constructor_expanddim)
#     17675    0.010    0.000    0.010    0.000 statistics.py:200(_exact_ratio)
#      4890    0.010    0.000    0.152    0.000 api.py:109(_get_combined_index)
#     66376    0.010    0.000    0.010    0.000 {method 'append' of 'list' objects}
#      4890    0.010    0.000    0.020    0.000 managers.py:1979(_preprocess_slice_or_indexer)
#      4890    0.010    0.000    0.181    0.000 concat.py:524(_get_comb_axis)
#      9780    0.010    0.000    0.029    0.000 base.py:4711(_maybe_promote)
#      4890    0.010    0.000    0.223    0.000 indexing.py:864(__getitem__)
#     14890    0.010    0.000    0.010    0.000 <ipython-input-242-ec43a157a203>:14(<genexpr>)
#     12567    0.010    0.000    0.028    0.000 managers.py:296(__len__)
#     12567    0.010    0.000    0.010    0.000 {built-in method builtins.sorted}
#     19561    0.010    0.000    0.525    0.000 managers.py:153(blknos)
#     19560    0.009    0.000    0.014    0.000 missing.py:665(clean_reindex_fill_method)
#     14670    0.009    0.000    0.096    0.000 generic.py:5199(_consolidate_inplace)
#      4890    0.009    0.000    0.017    0.000 base.py:550(_engine)
#      9780    0.009    0.000    0.017    0.000 common.py:97(stringify_path)
#      4890    0.009    0.000    0.089    0.000 config.py:402(__enter__)
#      4891    0.009    0.000    0.055    0.000 algorithms.py:178(_reconstruct_data)
#     34230    0.009    0.000    0.009    0.000 base.py:586(dtype)
#      9780    0.009    0.000    0.103    0.000 base.py:1679(is_boolean)
#      4890    0.009    0.000    0.024    0.000 base.py:1210(_set_names)
#      9780    0.009    0.000    1.281    0.000 <ipython-input-250-5169d0567ee5>:16(<genexpr>)
#      7676    0.009    0.000    0.024    0.000 fractions.py:423(_div)
#      9782    0.009    0.000    0.026    0.000 common.py:348(is_datetime64_dtype)
#      9780    0.009    0.000    0.032    0.000 construction.py:575(is_empty_data)
#     24450    0.009    0.000    0.074    0.000 _methods.py:47(_all)
#      4890    0.009    0.000    0.020    0.000 base.py:1187(_validate_names)
#      9780    0.009    0.000    0.094    0.000 base.py:1994(inferred_type)
#      4890    0.009    0.000    0.068    0.000 cast.py:1627(maybe_cast_to_integer_array)
#      4890    0.009    0.000    3.733    0.001 generic.py:220(apply)
#      4890    0.009    0.000    1.078    0.000 concat.py:520(<listcomp>)
#      4890    0.009    0.000    0.292    0.000 generic.py:1633(__getitem__)
#      9781    0.009    0.000    0.033    0.000 generic.py:1716(__contains__)
#      4891    0.009    0.000    0.010    0.000 ops.py:88(__init__)
#      4890    0.008    0.000    0.067    0.000 base.py:1240(set_names)
#      4890    0.008    0.000    0.011    0.000 api.py:95(_get_distinct_objs)
#     14671    0.008    0.000    0.019    0.000 numeric.py:81(_validate_dtype)
#      9780    0.008    0.000    0.103    0.000 <__array_function__ internals>:2(array_equal)
#      9781    0.008    0.000    0.010    0.000 base.py:1207(_get_names)
#     14670    0.008    0.000    0.008    0.000 {method 'pop' of 'list' objects}
#      4890    0.008    0.000    0.028    0.000 generic.py:562(_set_axis)
#      4890    0.008    0.000    0.021    0.000 generic.py:4481(_needs_reindex_multi)
#     14671    0.008    0.000    0.008    0.000 {method 'split' of 'str' objects}
#      4890    0.008    0.000    0.199    0.000 base.py:5198(delete)
#      4891    0.008    0.000    0.022    0.000 grouper.py:825(_convert_grouper)
#     44020    0.008    0.000    0.008    0.000 {pandas._libs.lib.is_float}
#      4890    0.008    0.000    1.088    0.000 concat.py:517(_get_new_axes)
#     19562    0.008    0.000    0.010    0.000 common.py:329(apply_if_callable)
#     14670    0.008    0.000    0.039    0.000 managers.py:932(consolidate)
#     14672    0.007    0.000    0.047    0.000 managers.py:647(is_consolidated)
#     24450    0.007    0.000    0.011    0.000 inference.py:289(<genexpr>)
#      4891    0.007    0.000    0.196    0.000 algorithms.py:263(_get_data_algo)
#      4891    0.007    0.000    0.024    0.000 indexers.py:348(check_array_indexer)
#     24452    0.007    0.000    0.007    0.000 generic.py:232(attrs)
#      4891    0.007    0.000    0.198    0.000 ops.py:924(slabels)
#      4890    0.007    0.000    0.260    0.000 <ipython-input-250-5169d0567ee5>:9(partial_fit)
#      9780    0.007    0.000    0.007    0.000 {built-in method _abc._abc_subclasscheck}
#      4890    0.007    0.000    0.063    0.000 config.py:408(__exit__)
#      4891    0.007    0.000    0.008    0.000 ops.py:916(__init__)
#      7676    0.007    0.000    0.047    0.000 fractions.py:386(reverse)
#      4890    0.007    0.000    0.014    0.000 managers.py:210(set_axis)
#      4890    0.007    0.000    4.357    0.001 frame.py:4028(drop)
#     19560    0.007    0.000    0.060    0.000 common.py:603(<genexpr>)
#      4890    0.007    0.000    0.047    0.000 common.py:241(index_labels_to_array)
#      4890    0.007    0.000    0.029    0.000 blocks.py:2368(__init__)
#      4890    0.007    0.000    0.018    0.000 common.py:363(standardize_mapping)
#     24455    0.007    0.000    0.007    0.000 blocks.py:229(fill_value)
#      3450    0.006    0.000    0.006    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#      9780    0.006    0.000    0.009    0.000 generic.py:372(_get_axis_name)
#     19560    0.006    0.000    0.007    0.000 base.py:420(<genexpr>)
#     14671    0.006    0.000    0.012    0.000 generic.py:447(_info_axis)
#     34234    0.006    0.000    0.006    0.000 ops.py:107(groupings)
#     14678    0.006    0.000    0.069    0.000 _methods.py:44(_any)
#     17457    0.006    0.000    0.048    0.000 {built-in method builtins.iter}
#     14670    0.006    0.000    0.006    0.000 config.py:539(_select_options)
#      4890    0.006    0.000    0.013    0.000 csvs.py:233(_save_header)
#      4890    0.006    0.000    0.014    0.000 base.py:3109(_validate_positional_slice)
#      4891    0.006    0.000    0.904    0.000 ops.py:269(group_info)
#      4890    0.006    0.000    0.029    0.000 numeric.py:159(ones)
#     14671    0.006    0.000    0.006    0.000 base.py:1749(is_floating)
#     14670    0.006    0.000    0.018    0.000 config.py:598(_translate_key)
#      4890    0.006    0.000    0.166    0.000 api.py:65(get_objs_combined_axis)
#     35677    0.006    0.000    0.006    0.000 {pandas._libs.algos.ensure_platform_int}
#      4891    0.006    0.000    0.014    0.000 ops.py:977(get_splitter)
#      4890    0.006    0.000    0.029    0.000 generic.py:5207(_consolidate)
#      4891    0.006    0.000    0.016    0.000 ops.py:149(_get_group_keys)
#     14673    0.006    0.000    0.007    0.000 base.py:4979(_validate_indexer)
#      4890    0.006    0.000    0.052    0.000 series.py:1483(items)
#      4890    0.005    0.000    0.018    0.000 concat.py:380(<listcomp>)
#      9782    0.005    0.000    0.854    0.000 grouper.py:563(codes)
#     14670    0.005    0.000    0.008    0.000 base.py:3890(_get_engine_target)
#      4890    0.005    0.000    0.115    0.000 common.py:1123(is_datetimelike_v_numeric)
#      4890    0.005    0.000    0.170    0.000 <__array_function__ internals>:2(delete)
#      4890    0.005    0.000    0.033    0.000 config.py:104(_get_option)
#      4891    0.005    0.000    0.371    0.000 ops.py:122(get_iterator)
#      4890    0.005    0.000    0.007    0.000 frozen.py:66(__getitem__)
#     23028    0.005    0.000    0.005    0.000 {built-in method math.gcd}
#      7676    0.005    0.000    0.030    0.000 fractions.py:374(forward)
#      4890    0.005    0.000    3.102    0.001 _decorators.py:307(wrapper)
#      4891    0.005    0.000    0.065    0.000 ops.py:929(sort_idx)
#      4891    0.005    0.000    0.863    0.000 ops.py:230(codes)
#      4890    0.005    0.000    0.013    0.000 frame.py:584(shape)
#      4890    0.005    0.000    0.005    0.000 groupby.py:697(__getattr__)
#      4890    0.005    0.000    0.014    0.000 typing.py:713(__subclasscheck__)
#      4891    0.005    0.000    0.009    0.000 generic.py:3573(_set_is_copy)
#      4890    0.005    0.000    0.021    0.000 construction.py:274(<listcomp>)
#      4890    0.005    0.000    0.076    0.000 base.py:4114(_can_hold_identifiers_and_holds_name)
#     19560    0.005    0.000    0.005    0.000 missing.py:75(clean_fill_method)
#     12567    0.005    0.000    0.038    0.000 series.py:595(__len__)
#      4890    0.005    0.000    0.038    0.000 config.py:403(<listcomp>)
#      4892    0.005    0.000    0.005    0.000 masked.py:65(__init__)
#     19561    0.005    0.000    0.005    0.000 managers.py:169(blklocs)
#     32126    0.005    0.000    0.005    0.000 {method 'items' of 'dict' objects}
#      4890    0.005    0.000    0.006    0.000 groupby.py:2668(_reindex_output)
#      4890    0.005    0.000    0.070    0.000 common.py:598(is_excluded_dtype)
#     34231    0.005    0.000    0.005    0.000 numeric.py:150(is_all_dates)
#      4891    0.004    0.000    0.038    0.000 managers.py:146(from_blocks)
#      9780    0.004    0.000    0.010    0.000 base.py:4283(<genexpr>)
#      4890    0.004    0.000    0.005    0.000 groupby.py:632(_selected_obj)
#      4891    0.004    0.000    0.009    0.000 ops.py:234(levels)
#      4890    0.004    0.000    0.007    0.000 ops.py:238(names)
#      4890    0.004    0.000    0.019    0.000 typing.py:710(__instancecheck__)
#      9782    0.004    0.000    0.005    0.000 grouper.py:703(<genexpr>)
#     24454    0.004    0.000    0.004    0.000 {pandas._libs.lib.is_integer}
#      7677    0.004    0.000    0.007    0.000 ops.py:900(_is_indexed_like)
#      4890    0.004    0.000    0.012    0.000 common.py:211(count_not_none)
#      4891    0.004    0.000    0.126    0.000 algorithms.py:255(_get_values_for_rank)
#      9782    0.004    0.000    0.021    0.000 managers.py:948(_consolidate_inplace)
#      9780    0.004    0.000    0.006    0.000 _validators.py:208(validate_bool_kwarg)
#      9782    0.004    0.000    0.006    0.000 grouper.py:706(<genexpr>)
#     17457    0.004    0.000    0.004    0.000 managers.py:249(items)
#      4890    0.004    0.000    0.210    0.000 indexing.py:1474(_getitem_axis)
#      4890    0.004    0.000    0.009    0.000 common.py:1509(is_complex_dtype)
#      9780    0.004    0.000    0.006    0.000 managers.py:313(<genexpr>)
#     15352    0.004    0.000    0.004    0.000 statistics.py:169(_coerce)
#      4890    0.004    0.000    0.004    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      4891    0.004    0.000    0.857    0.000 ops.py:232(<listcomp>)
#     14671    0.004    0.000    0.004    0.000 {method 'upper' of 'str' objects}
#      4890    0.004    0.000    0.011    0.000 base.py:626(shape)
#     14670    0.004    0.000    0.005    0.000 managers.py:1647(<genexpr>)
#      9780    0.004    0.000    0.011    0.000 abc.py:141(__subclasscheck__)
#     23672    0.004    0.000    0.004    0.000 fractions.py:278(denominator)
#      4890    0.003    0.000    0.046    0.000 blocks.py:670(copy)
#      9780    0.003    0.000    0.006    0.000 config.py:587(_get_registered_option)
#      7677    0.003    0.000    0.003    0.000 series.py:810(axes)
#     14672    0.003    0.000    0.003    0.000 {pandas._libs.lib.item_from_zerodim}
#      4890    0.003    0.000    0.005    0.000 base.py:569(_is_builtin_func)
#      4890    0.003    0.000    0.014    0.000 managers.py:1813(_asarray_compat)
#      4893    0.003    0.000    0.015    0.000 inference.py:185(is_array_like)
#      4890    0.003    0.000    0.009    0.000 api.py:91(<listcomp>)
#     19563    0.003    0.000    0.003    0.000 {pandas._libs.lib.is_bool}
#      4890    0.003    0.000    0.004    0.000 generic.py:3243(_clear_item_cache)
#      4890    0.003    0.000    0.026    0.000 managers.py:1819(_shape_compat)
#      4890    0.003    0.000    0.003    0.000 {pandas._libs.internals.get_blkno_placements}
#      9790    0.003    0.000    0.003    0.000 {built-in method pandas._libs.missing.checknull}
#      4890    0.003    0.000    0.027    0.000 common.py:269(get_compression_method)
#         1    0.003    0.003    0.003    0.003 {built-in method io.open}
#     24453    0.003    0.000    0.003    0.000 {built-in method builtins.callable}
#       161    0.003    0.000    0.008    0.000 std.py:340(format_meter)
#      9781    0.003    0.000    0.003    0.000 function.py:48(__call__)
#      4890    0.003    0.000    0.003    0.000 {built-in method builtins.min}
#      9780    0.003    0.000    0.003    0.000 config.py:804(inner)
#     14670    0.003    0.000    0.003    0.000 multiarray.py:1043(copyto)
#      4890    0.003    0.000    0.010    0.000 common.py:302(infer_compression)
#      4890    0.003    0.000    0.003    0.000 {pandas._libs.lib.infer_datetimelike_array}
#      9782    0.003    0.000    0.003    0.000 grouper.py:575(group_index)
#     19561    0.003    0.000    0.003    0.000 base.py:1372(nlevels)
#      8482    0.003    0.000    0.003    0.000 {built-in method unicodedata.east_asian_width}
#     14670    0.003    0.000    0.003    0.000 series.py:381(_constructor)
#     14670    0.003    0.000    0.003    0.000 common.py:215(<genexpr>)
#      4890    0.003    0.000    0.003    0.000 indexing.py:100(iloc)
#      9780    0.003    0.000    0.004    0.000 common.py:67(_expand_user)
#      7032    0.003    0.000    0.003    0.000 fractions.py:504(__trunc__)
#      4890    0.003    0.000    0.003    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#      4890    0.003    0.000    0.004    0.000 ops.py:118(nkeys)
#     19560    0.003    0.000    0.003    0.000 base.py:637(ndim)
#      4891    0.003    0.000    0.018    0.000 algorithms.py:213(_ensure_arraylike)
#      4890    0.003    0.000    0.003    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#      4890    0.003    0.000    0.008    0.000 construction.py:278(<listcomp>)
#      4890    0.003    0.000    0.003    0.000 common.py:176(not_none)
#      4890    0.003    0.000    0.009    0.000 managers.py:1797(<lambda>)
#      4890    0.003    0.000    0.033    0.000 construction.py:281(<listcomp>)
#     15996    0.003    0.000    0.003    0.000 fractions.py:274(numerator)
#      4890    0.003    0.000    0.006    0.000 common.py:312(get_callable_name)
#      4890    0.002    0.000    0.009    0.000 common.py:1265(is_string_like_dtype)
#     14671    0.002    0.000    0.002    0.000 multiarray.py:469(can_cast)
#      4891    0.002    0.000    0.002    0.000 frame.py:567(axes)
#      4890    0.002    0.000    0.005    0.000 inference.py:96(is_file_like)
#      4891    0.002    0.000    0.004    0.000 ops.py:236(<listcomp>)
#      4891    0.002    0.000    0.014    0.000 blocks.py:1614(_maybe_coerce_values)
#      4890    0.002    0.000    0.002    0.000 base.py:1640(is_unique)
#      4890    0.002    0.000    0.002    0.000 generic.py:168(_selection_name)
#      9780    0.002    0.000    0.002    0.000 common.py:180(<genexpr>)
#      9782    0.002    0.000    0.003    0.000 grouper.py:704(<genexpr>)
#      8643    0.002    0.000    0.005    0.000 utils.py:405(<genexpr>)
#      4891    0.002    0.000    0.003    0.000 grouper.py:821(_is_label_like)
#      4890    0.002    0.000    0.003    0.000 managers.py:223(_is_single_block)
#      4890    0.002    0.000    0.007    0.000 base.py:5615(ensure_has_len)
#      7677    0.002    0.000    0.002    0.000 managers.py:1565(index)
#      9782    0.002    0.000    0.002    0.000 frame.py:420(_constructor)
#      4891    0.002    0.000    0.008    0.000 _asarray.py:88(asanyarray)
#      4890    0.002    0.000    0.003    0.000 inspect.py:72(isclass)
#      4890    0.002    0.000    0.002    0.000 ops.py:240(<listcomp>)
#     14670    0.002    0.000    0.002    0.000 {pandas._libs.lib.is_iterator}
#       647    0.002    0.000    0.034    0.000 iostream.py:197(schedule)
#      4891    0.002    0.000    0.005    0.000 grouper.py:739(is_in_axis)
#      4890    0.002    0.000    0.002    0.000 common.py:1293(<lambda>)
#      5051    0.002    0.000    0.002    0.000 {method 'update' of 'dict' objects}
#      9784    0.002    0.000    0.002    0.000 {method 'add' of 'set' objects}
#      9780    0.002    0.000    0.002    0.000 numeric.py:2283(_array_equal_dispatcher)
#      4890    0.002    0.000    0.002    0.000 indexing.py:2270(need_slice)
#      4891    0.002    0.000    0.003    0.000 grouper.py:752(is_in_obj)
#      4890    0.002    0.000    0.002    0.000 concat.py:511(_get_result_dim)
#      9780    0.002    0.000    0.002    0.000 {method 'keys' of 'dict' objects}
#      4890    0.002    0.000    0.002    0.000 base.py:3269(_can_reindex)
#      4890    0.002    0.000    0.002    0.000 blocks.py:311(shape)
#      4890    0.002    0.000    0.002    0.000 common.py:140(is_fsspec_url)
#      9780    0.001    0.000    0.001    0.000 {method 'copy' of 'dict' objects}
#        11    0.001    0.000    0.001    0.000 {built-in method sys.intern}
#      9780    0.001    0.000    0.001    0.000 managers.py:1588(is_consolidated)
#         1    0.001    0.001    0.001    0.001 {built-in method posix.read}
#      4891    0.001    0.000    0.001    0.000 generic.py:1493(<genexpr>)
#         1    0.001    0.001    0.014    0.014 subprocess.py:1383(_execute_child)
#      9782    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#         1    0.001    0.001   16.543   16.543 {built-in method builtins.exec}
#       163    0.001    0.000    0.001    0.000 threading.py:216(__init__)
#       161    0.001    0.000    0.001    0.000 std.py:1480(format_dict)
#      4890    0.001    0.000    0.001    0.000 function_base.py:4214(_delete_dispatcher)
#       808    0.001    0.000    0.002    0.000 threading.py:1092(is_alive)
#      4890    0.001    0.000    0.001    0.000 {pandas._libs.algos.ensure_object}
#       163    0.001    0.000    0.033    0.000 iostream.py:384(write)
#       161    0.001    0.000    0.090    0.001 threading.py:264(wait)
#      4890    0.001    0.000    0.001    0.000 {method 'clear' of 'dict' objects}
#       161    0.001    0.000    0.098    0.001 iostream.py:336(flush)
#      4890    0.001    0.000    0.001    0.000 {method 'extend' of 'list' objects}
#      4890    0.001    0.000    0.001    0.000 base.py:557(<lambda>)
#       322    0.001    0.000    0.001    0.000 utils.py:297(_is_ascii)
#      4890    0.001    0.000    0.001    0.000 {method 'values' of 'dict' objects}
#       164    0.001    0.000    0.001    0.000 {method 'acquire' of '_multiprocessing.SemLock' objects}
#       160    0.001    0.000    0.152    0.001 std.py:1367(refresh)
#       161    0.001    0.000    0.010    0.000 std.py:1133(__repr__)
#       162    0.001    0.000    0.092    0.001 threading.py:534(wait)
#       324    0.001    0.000    0.131    0.000 utils.py:224(inner)
#       161    0.001    0.000    0.001    0.000 std.py:182(__format__)
#      4890    0.001    0.000    0.001    0.000 {function FrozenList.__getitem__ at 0x7fb60a90bd40}
#       164    0.001    0.000    0.001    0.000 {method 'release' of '_multiprocessing.SemLock' objects}
#       161    0.001    0.000    0.149    0.001 std.py:1498(display)
#       161    0.001    0.000    0.139    0.001 std.py:333(print_status)
#       644    0.000    0.000    0.001    0.000 numbers.py:283(__float__)
#       164    0.000    0.000    0.001    0.000 std.py:90(release)
#       161    0.000    0.000    0.131    0.001 std.py:327(fp_write)
#       809    0.000    0.000    0.001    0.000 threading.py:1050(_wait_for_tstate_lock)
#       163    0.000    0.000    0.003    0.000 iostream.py:322(_schedule_flush)
#       164    0.000    0.000    0.001    0.000 std.py:86(acquire)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.open}
#       321    0.000    0.000    0.001    0.000 std.py:257(format_interval)
#       647    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#      3381    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#       161    0.000    0.000    0.000    0.000 {method 'sub' of 're.Pattern' objects}
#       163    0.000    0.000    0.001    0.000 threading.py:499(__init__)
#       161    0.000    0.000    0.000    0.000 std.py:149(__init__)
#       161    0.000    0.000    0.007    0.000 utils.py:408(disp_len)
#       318    0.000    0.000    0.000    0.000 std.py:298(ema)
#       163    0.000    0.000    0.000    0.000 iostream.py:309(_is_master_process)
#       812    0.000    0.000    0.000    0.000 threading.py:507(is_set)
#       325    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       161    0.000    0.000    0.006    0.000 utils.py:403(_text_width)
#       161    0.000    0.000    0.000    0.000 threading.py:252(_acquire_restore)
#       643    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis0_float32_float32}
#       803    0.000    0.000    0.000    0.000 {built-in method builtins.divmod}
#       163    0.000    0.000    0.000    0.000 threading.py:243(__exit__)
#       161    0.000    0.000    0.000    0.000 utils.py:140(__init__)
#       163    0.000    0.000    0.000    0.000 threading.py:240(__enter__)
#       808    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.015    0.015 chime.py:33(run)
#       161    0.000    0.000    0.000    0.000 utils.py:144(__format__)
#       161    0.000    0.000    0.000    0.000 std.py:163(colour)
#       164    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#       161    0.000    0.000    0.000    0.000 threading.py:249(_release_save)
#       162    0.000    0.000    0.000    0.000 threading.py:255(_is_owned)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis0_int32_int32}
#         1    0.000    0.000    0.000    0.000 {built-in method _warnings.warn}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#         1    0.000    0.000    0.016    0.016 chime.py:126(success)
#       161    0.000    0.000    0.000    0.000 std.py:159(colour)
#         1    0.000    0.000    0.014    0.014 subprocess.py:656(__init__)
#       163    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#       163    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#       164    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis0_int64_int64}
#       161    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#         1    0.000    0.000    0.001    0.001 std.py:835(__init__)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_bool_bool}
#       165    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis1_int8_int8}
#       163    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis1_int16_int16}
#       163    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.015    0.015 chime.py:45(play_wav)
#         2    0.000    0.000    0.000    0.000 subprocess.py:1544(_internal_poll)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#         1    0.000    0.000    0.000    0.000 indexers.py:210(maybe_convert_indices)
#         1    0.000    0.000    0.001    0.001 algorithms.py:1961(safe_sort)
#         1    0.000    0.000    0.001    0.001 managers.py:1252(<listcomp>)
#         1    0.000    0.000    0.001    0.001 managers.py:1394(take)
#         4    0.000    0.000    0.001    0.000 pathlib.py:63(parse_parts)
#         1    0.000    0.000    0.000    0.000 subprocess.py:850(__del__)
#         1    0.000    0.000    0.001    0.001 chime.py:74(themes_dir)
#         2    0.000    0.000    0.000    0.000 algorithms.py:1493(take)
#         3    0.000    0.000    0.000    0.000 {built-in method posix.close}
#         1    0.000    0.000    0.000    0.000 _monitor.py:32(__init__)
#         1    0.000    0.000    0.000    0.000 indexing.py:2128(convert_to_index_sliceable)
#         1    0.000    0.000    0.000    0.000 {method 'writerow' of '_csv.writer' objects}
#         1    0.000    0.000    0.000    0.000 std.py:549(__new__)
#         1    0.000    0.000    0.000    0.000 utils.py:356(_screen_shape_linux)
#         1    0.000    0.000    0.016    0.016 chime.py:119(notify)
#         1    0.000    0.000    0.000    0.000 std.py:578(_decr_instances)
#         1    0.000    0.000    0.000    0.000 threading.py:763(__init__)
#         2    0.000    0.000    0.000    0.000 indexers.py:166(validate_indices)
#         1    0.000    0.000    0.000    0.000 blocks.py:1636(fill_value)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.waitpid}
#         1    0.000    0.000    0.000    0.000 threading.py:834(start)
#         4    0.000    0.000    0.001    0.000 pathlib.py:640(_parse_args)
#         1    0.000    0.000    0.002    0.002 generic.py:3249(take)
#         1    0.000    0.000    0.001    0.001 std.py:1311(close)
#         1    0.000    0.000    0.000    0.000 {built-in method atexit.register}
#         1    0.000    0.000    0.000    0.000 _bootlocale.py:33(getpreferredencoding)
#         1    0.000    0.000    0.000    0.000 base.py:3118(_convert_slice_indexer)
#         1    0.000    0.000    0.000    0.000 {built-in method posix.pipe}
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#         2    0.000    0.000    0.000    0.000 algorithms.py:1297(wrapper)
#         1    0.000    0.000    0.000    0.000 masked.py:253(take)
#         1    0.000    0.000    0.000    0.000 blocks.py:1707(take_nd)
#         2    0.000    0.000    0.000    0.000 std.py:1328(fp_write)
#         1    0.000    0.000    0.000    0.000 <ipython-input-250-5169d0567ee5>:5(__init__)
#         3    0.000    0.000    0.000    0.000 threading.py:1226(current_thread)
#         3    0.000    0.000    0.000    0.000 pathlib.py:694(_make_child)
#         1    0.000    0.000    0.000    0.000 {built-in method fcntl.ioctl}
#         4    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 _monitor.py:50(exit)
#         1    0.000    0.000    0.000    0.000 os.py:673(__getitem__)
#         1    0.000    0.000    0.000    0.000 posixpath.py:154(dirname)
#         1    0.000    0.000    0.000    0.000 subprocess.py:865(_get_devnull)
#         1    0.000    0.000    0.000    0.000 {built-in method _locale.nl_langinfo}
#         1    0.000    0.000    0.000    0.000 <ipython-input-242-ec43a157a203>:5(__init__)
#         1    0.000    0.000    0.000    0.000 utils.py:237(__init__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:106(remove)
#         1    0.000    0.000    0.000    0.000 subprocess.py:226(_cleanup)
#         1    0.000    0.000    0.000    0.000 threading.py:335(notify)
#         1    0.000    0.000    0.000    0.000 threading.py:513(set)
#         1    0.000    0.000    0.001    0.001 pathlib.py:660(_from_parts)
#         1    0.000    0.000    0.000    0.000 pathlib.py:683(_format_parsed_parts)
#         1    0.000    0.000    0.001    0.001 pathlib.py:1007(__new__)
#         2    0.000    0.000    0.000    0.000 {method 'remove' of 'set' objects}
#         3    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 std.py:94(__enter__)
#         1    0.000    0.000    0.001    0.001 chime.py:80(current_theme_dir)
#         1    0.000    0.000    0.000    0.000 <ipython-input-250-5169d0567ee5>:6(<listcomp>)
#         1    0.000    0.000    0.000    0.000 os.py:751(encode)
#         1    0.000    0.000    0.000    0.000 utils.py:370(<listcomp>)
#         3    0.000    0.000    0.000    0.000 utils.py:184(wrapper_setattr)
#         1    0.000    0.000    0.000    0.000 subprocess.py:1526(_handle_exitstatus)
#         1    0.000    0.000    0.000    0.000 threading.py:728(_newname)
#         1    0.000    0.000    0.000    0.000 threading.py:977(_stop)
#         1    0.000    0.000    0.000    0.000 threading.py:1012(join)
#         4    0.000    0.000    0.000    0.000 pathlib.py:291(splitroot)
#         4    0.000    0.000    0.000    0.000 pathlib.py:673(_from_parsed_parts)
#         3    0.000    0.000    0.000    0.000 base.py:3136(is_int)
#         4    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         1    0.000    0.000    0.000    0.000 std.py:317(status_printer)
#         1    0.000    0.000    0.000    0.000 std.py:661(get_lock)
#         2    0.000    0.000    0.000    0.000 std.py:1140(__hash__)
#        21    0.000    0.000    0.000    0.000 <ipython-input-242-ec43a157a203>:6(<lambda>)
#         1    0.000    0.000    0.000    0.000 os.py:803(fsencode)
#         1    0.000    0.000    0.000    0.000 utils.py:246(__eq__)
#         1    0.000    0.000    0.000    0.000 utils.py:157(__eq__)
#         1    0.000    0.000    0.000    0.000 subprocess.py:1329(_get_handles)
#         2    0.000    0.000    0.000    0.000 threading.py:1116(daemon)
#         3    0.000    0.000    0.000    0.000 pathlib.py:101(join_parsed_parts)
#         2    0.000    0.000    0.000    0.000 pathlib.py:700(__str__)
#         3    0.000    0.000    0.000    0.000 pathlib.py:899(joinpath)
#         1    0.000    0.000    0.000    0.000 pathlib.py:1163(stat)
#         1    0.000    0.000    0.000    0.000 pathlib.py:1341(exists)
#         1    0.000    0.000    0.000    0.000 missing.py:255(notna)
#         1    0.000    0.000    0.000    0.000 groupby.py:814(__iter__)
#         1    0.000    0.000    0.000    0.000 {method 'rfind' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'rstrip' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'lstrip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.WIFSIGNALED}
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'min' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 std.py:97(__exit__)
#         2    0.000    0.000    0.000    0.000 std.py:1136(_comparable)
#         1    0.000    0.000    0.000    0.000 codecs.py:186(__init__)
#         1    0.000    0.000    0.000    0.000 posixpath.py:41(_get_sep)
#         2    0.000    0.000    0.000    0.000 utils.py:219(disable_on_exception)
#         1    0.000    0.000    0.000    0.000 utils.py:276(_is_utf)
#         1    0.000    0.000    0.000    0.000 utils.py:290(_supports_unicode)
#         1    0.000    0.000    0.000    0.000 utils.py:306(_screen_shape_wrapper)
#         1    0.000    0.000    0.000    0.000 _monitor.py:102(report)
#         1    0.000    0.000    0.000    0.000 utils.py:188(__init__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:67(__len__)
#         1    0.000    0.000    0.000    0.000 threading.py:1132(daemon)
#         1    0.000    0.000    0.000    0.000 platform.py:923(uname)
#         1    0.000    0.000    0.000    0.000 platform.py:1061(system)
#         1    0.000    0.000    0.000    0.000 pathlib.py:710(__fspath__)
#         1    0.000    0.000    0.000    0.000 pathlib.py:913(parent)
#         5    0.000    0.000    0.000    0.000 pathlib.py:1017(_init)
#         1    0.000    0.000    0.000    0.000 multiarray.py:584(min_scalar_type)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(min_scalar_type)
#         2    0.000    0.000    0.000    0.000 _methods.py:32(_amin)
#         1    0.000    0.000    0.000    0.000 boolean.py:271(dtype)
#         2    0.000    0.000    0.000    0.000 base.py:1714(is_integer)
#         2    0.000    0.000    0.000    0.000 numeric.py:237(inferred_type)
#         1    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#         3    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 <ipython-input-250-5169d0567ee5>:7(<listcomp>)
#         2    0.000    0.000    0.000    0.000 utils.py:171(__getattr__)
#         1    0.000    0.000    0.000    0.000 threading.py:358(notify_all)
